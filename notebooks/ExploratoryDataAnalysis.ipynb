# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# plot style
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 110

# %%
df=pd.read_csv('../data/processed/Books_Cleaned.csv')

# %%
df.columns
# Out:
# Index(['book_id', 'title', 'authors', 'series', 'language', 'description',
#        'genres', 'characters', 'places', 'awards', 'rating', 'rating_count',
#        'review_count', 'popularity_score', 'award_count', 'pages',
#        'first_publish_year', 'publish_year', 'rated_1', 'rated_2', 'rated_3',
#        'rated_4', 'rated_5', 'isbn', 'isbn13'],
#       dtype='str')

# %%
print("Total books   :", len(df))
print("Total columns :", df.shape[1])
print()
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Total books   : 16122
# Total columns : 25
#
# Missing values per column:
# book_id                   0
# title                     0
# authors                   0
# series                    0
# language                  0
# description            1412
# genres                    0
# characters            12655
# places                13225
# awards                13895
# rating                    0
# rating_count              0
# review_count              0
# popularity_score          0
# award_count               0
# pages                     0
# first_publish_year     4567
# publish_year              0
# rated_1                   0
# rated_2                   0
# rated_3                   0
# rated_4                   0
# rated_5                   0
# isbn                   1608
# isbn13                  202
# dtype: int64

# %%
df.head(2)
# Out:
#    book_id                                     title  \
# 0     4255  Harry Potter and the Philosopher's Stone
# 1        3     Harry Potter and the Sorcerer's Stone
#
#                       authors           series language  \
# 0                J.K. Rowling  Harry Potter #1  English
# 1  J.K. Rowling,Mary GrandPré  Harry Potter #1  English
#
#                                          description  \
# 0  When a letter arrives for unhappy but ordinary...
# 1  Harry Potter's life is miserable. His parents ...
#
#                                               genres  \
# 0  Fantasy,Fiction,Young Adult,Magic,Childrens,Mi...
# 1  Fantasy,Fiction,Young Adult,Magic,Childrens,Mi...
#
#                                           characters  \
# 0  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 1  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
#
#                                               places  \
# 0  London, England,Hogwarts School of Witchcraft ...
# 1  London, England,Hogwarts School of Witchcraft ...
#
#                                               awards  ...  pages  \
# 0  Mythopoeic Fantasy Award for Children's Litera...  ...    223
# 1  Mythopoeic Fantasy Award for Children's Litera...  ...    309
#
#    first_publish_year  publish_year  rated_1  rated_2  rated_3  rated_4  \
# 0              1997.0          2004   126396   147247   627970  1694668
# 1              1997.0          2003   126344   147184   627803  1694206
#
#    rated_5  isbn  isbn13
# 0  4840724   NaN     NaN
# 1  4839246   NaN     NaN
#
# [2 rows x 25 columns]
